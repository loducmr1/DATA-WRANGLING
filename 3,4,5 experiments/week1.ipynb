# %%
# !pip install pandas

# %%
#Discovery
import pandas as pd
df=pd.read_csv('Customer.csv')
df
# Out:
#     Customer ID      Customer Name      Segment  Age        Country  \
# 0      CG-12520        Claire Gute     Consumer   67  United States
# 1      DV-13045    Darrin Van Huff    Corporate   31  United States
# 2      SO-20335     Sean O'Donnell     Consumer   65  United States
# 3      BH-11710    Brosina Hoffman     Consumer   20  United States
# 4      AA-10480       Andrew Allen     Consumer   50  United States
# ..          ...                ...          ...  ...            ...
# 788    CJ-11875       Carl Jackson    Corporate   64  United States
# 789    RS-19870         Roy Skaria  Home Office   39  United States
# 790    SC-20845         Sung Chung     Consumer   69  United States
# 791    RE-19405    Ricardo Emerson     Consumer   35  United States
# 792    SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                   City           State  Postal Code   Region
# 0            Henderson        Kentucky        42420    South
# ...

# %%
#Structuring
df.dtypes
# Out:
# Customer ID      object
# Customer Name    object
# Segment          object
# Age               int64
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# dtype: object

# %%
df.shape
# Out:
# (793, 9)

# %%
df.head(10)
# Out:
#   Customer ID       Customer Name      Segment  Age        Country  \
# 0    CG-12520         Claire Gute     Consumer   67  United States
# 1    DV-13045     Darrin Van Huff    Corporate   31  United States
# 2    SO-20335      Sean O'Donnell     Consumer   65  United States
# 3    BH-11710     Brosina Hoffman     Consumer   20  United States
# 4    AA-10480        Andrew Allen     Consumer   50  United States
# 5    IM-15070        Irene Maddox     Consumer   66  United States
# 6    HP-14815       Harold Pawlan  Home Office   20  United States
# 7    PK-19075           Pete Kriz     Consumer   46  United States
# 8    AG-10270     Alejandro Grove     Consumer   18  United States
# 9    ZD-21925  Zuschuss Donatelli     Consumer   66  United States
#
#               City           State  Postal Code   Region
# 0        Henderson        Kentucky        42420    South
# 1      Los Angeles      California        90036     West
# 2  Fort Lauderdale         Florida        33311    South
# ...

# %%
df.tail()
# Out:
#     Customer ID      Customer Name      Segment  Age        Country  \
# 788    CJ-11875       Carl Jackson    Corporate   64  United States
# 789    RS-19870         Roy Skaria  Home Office   39  United States
# 790    SC-20845         Sung Chung     Consumer   69  United States
# 791    RE-19405    Ricardo Emerson     Consumer   35  United States
# 792    SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                   City         State  Postal Code   Region
# 788       Philadelphia  Pennsylvania        19140     East
# 789         Burlington          Iowa        52601  Central
# 790  Arlington Heights      Illinois        60004  Central
# 791               Kent          Ohio        44240     East
# 792             Newark          Ohio        43055     East

# %%
#Data standarization and normalization
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer ID    793 non-null    object
#  1   Customer Name  793 non-null    object
#  2   Segment        793 non-null    object
#  3   Age            793 non-null    int64
#  4   Country        793 non-null    object
#  5   City           793 non-null    object
#  6   State          793 non-null    object
#  7   Postal Code    793 non-null    int64
#  8   Region         793 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 55.9+ KB

# %%
df.describe()
# Out:
#               Age   Postal Code
# count  793.000000    793.000000
# mean    44.467844  55229.717528
# std     15.526673  31679.223816
# min     18.000000   1841.000000
# 25%     31.000000  27217.000000
# 50%     45.000000  55901.000000
# 75%     58.000000  90004.000000
# max     70.000000  99207.000000

# %%
df['City'].count()
# Out:
# 793

# %%
df['City']=df['City'].str.lower()

# %%
df.head()
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
# 3    BH-11710  Brosina Hoffman   Consumer   20  United States
# 4    AA-10480     Andrew Allen   Consumer   50  United States
#
#               City           State  Postal Code Region
# 0        henderson        Kentucky        42420  South
# 1      los angeles      California        90036   West
# 2  fort lauderdale         Florida        33311  South
# 3      los angeles      California        90032   West
# 4          concord  North Carolina        28027  South

# %%
df['State']=df['State'].str.replace('Iowa','Ohio')

# %%
df.tail()
# Out:
#     Customer ID      Customer Name      Segment  Age        Country  \
# 788    CJ-11875       Carl Jackson    Corporate   64  United States
# 789    RS-19870         Roy Skaria  Home Office   39  United States
# 790    SC-20845         Sung Chung     Consumer   69  United States
# 791    RE-19405    Ricardo Emerson     Consumer   35  United States
# 792    SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                   City         State  Postal Code   Region
# 788       philadelphia  Pennsylvania        19140     East
# 789         burlington          Ohio        52601  Central
# 790  arlington heights      Illinois        60004  Central
# 791               kent          Ohio        44240     East
# 792             newark          Ohio        43055     East

# %%
#Data Cleaning
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 788    False
# 789    False
# 790    False
# 791    False
# 792    False
# Length: 793, dtype: bool

# %%
#find duplicates
df['Age'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 788     True
# 789     True
# 790     True
# 791     True
# 792     True
# Name: Age, Length: 793, dtype: bool

# %%
sum(df.duplicated())
# Out:
# 0

# %%
#outliers
df[df['Age'] < 40]
# Out:
#     Customer ID    Customer Name      Segment  Age        Country  \
# 1      DV-13045  Darrin Van Huff    Corporate   31  United States
# 3      BH-11710  Brosina Hoffman     Consumer   20  United States
# 6      HP-14815    Harold Pawlan  Home Office   20  United States
# 8      AG-10270  Alejandro Grove     Consumer   18  United States
# 12     EB-13870      Emily Burns     Consumer   34  United States
# ..          ...              ...          ...  ...            ...
# 781    AR-10570   Anemone Ratner     Consumer   36  United States
# 785    HE-14800     Harold Engle    Corporate   31  United States
# 787    HD-14785    Harold Dahlen  Home Office   32  United States
# 789    RS-19870       Roy Skaria  Home Office   39  United States
# 791    RE-19405  Ricardo Emerson     Consumer   35  United States
#
#              City         State  Postal Code   Region
# 1     los angeles    California        90036     West
# 3     los angeles    California        90032     West
# ...

# %%
#atleast one cell is NAN
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (793, 9)

# %%
#remove irrelevant data
df.drop(['Age','Segment'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#   Customer ID       Customer Name      Segment        Country  \
# 0    CG-12520         Claire Gute     Consumer  United States
# 1    DV-13045     Darrin Van Huff    Corporate  United States
# 2    SO-20335      Sean O'Donnell     Consumer  United States
# 3    BH-11710     Brosina Hoffman     Consumer  United States
# 4    AA-10480        Andrew Allen     Consumer  United States
# 5    IM-15070        Irene Maddox     Consumer  United States
# 6    HP-14815       Harold Pawlan  Home Office  United States
# 7    PK-19075           Pete Kriz     Consumer  United States
# 8    AG-10270     Alejandro Grove     Consumer  United States
# 9    ZD-21925  Zuschuss Donatelli     Consumer  United States
#
#               City           State  Postal Code   Region
# 0        Henderson        Kentucky        42420    South
# 1      Los Angeles      California        90036     West
# 2  Fort Lauderdale         Florida        33311    South
# ...

# %%
#Adding
df['Amount']=df['Postal Code']/50

# %%
df.head()
# Out:
#   Customer ID    Customer Name    Segment        Country             City  \
# 0    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 2    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 3    BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 4    AA-10480     Andrew Allen   Consumer  United States          Concord
#
#             State  Postal Code Region   Amount
# 0        Kentucky        42420  South   848.40
# 1      California        90036   West  1800.72
# 2         Florida        33311  South   666.22
# 3      California        90032   West  1800.64
# 4  North Carolina        28027  South   560.54
